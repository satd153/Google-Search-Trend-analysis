# %%
import seaborn as sns
import pandas as pd 
import time

from pytrends.request import TrendReq 
import matplotlib.pyplot as plt

# %%
Trending_topics = TrendReq(hl='en-US', tz=360)

# %%
kw_list=input().split(",")
# Out:
#  ABCD,word,world,world war,naitik mishra

# %%
kw_list
# Out:
# ['ABCD', 'word', 'world', 'world war', 'naitik mishra']

# %%
Trending_topics.build_payload(kw_list,cat=0, timeframe='today 12-m')
Trending_topics.build_payload(kw_list=kw_list, 
  cat=0, timeframe='today 12-m')

# %%
pd.set_option('future.no_silent_downcasting', True)
data = Trending_topics.interest_over_time() 
data.columns
# Out:
# Index(['ABCD', 'word', 'world', 'world war', 'naitik mishra', 'isPartial'], dtype='object')

# %%
data.columns
# Out:
# Index(['ABCD', 'word', 'world', 'world war', 'naitik mishra', 'isPartial'], dtype='object')

# %%
# data = data.sort_values(by=kw_list[0], ascending = False) 
# data = data.head(10) 
print(data)
# Out:
#             ABCD  word  world  world war  naitik mishra  isPartial
# date
# 2023-05-07     0    20     23          1              0      False
# 2023-05-14     0    20     23          1              0      False
# 2023-05-21     0    20     24          1              0      False
# 2023-05-28     0    20     25          1              0      False
# 2023-06-04     0    19     26          1              0      False
# 2023-06-11     0    20     25          1              0      False
# 2023-06-18     0    19     26          1              0      False
# 2023-06-25     0    17     27          1              0      False
# 2023-07-02     0    18     26          1              0      False
# 2023-07-09     0    17     23          1              0      False
# 2023-07-16     0    17     34          1              0      False
# 2023-07-23     0    17     34          1              0      False
# 2023-07-30     0    17     41          1              0      False
# ...

# %%
plt.figure(figsize=(8, 6))
sns.lineplot(data=data)
plt.title('Scatter Plot')
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=data, bins=5, kde=True)
plt.title('Histogram')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data)
plt.title('Box Plot')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=data)
plt.title('Scatter Plot')
plt.show()

# %%
sns.pairplot(data)

# %%
#interest by region
data = Trending_topics.interest_by_region() 
# data = data.sort_values(by=kw_list[0], 
#             ascending = False) 
print(data)
# Out:
#                 ABCD  word  world  world war  naitik mishra
# geoName
# Afghanistan        0     0      0          0              0
# Albania            0     0      0          0              0
# Algeria            0    62     37          1              0
# American Samoa     0     0      0          0              0
# Andorra            0     0      0          0              0
# ...              ...   ...    ...        ...            ...
# Western Sahara     0     0      0          0              0
# Yemen              0     0      0          0              0
# Zambia             0     0      0          0              0
# Zimbabwe           0     0      0          0              0
# Åland Islands      0     0      0          0              0
#
# [250 rows x 5 columns]

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(24,18))
sns.histplot(data=data, bins=5, kde=True)
plt.show()
plt.figure(figsize=(30,24))
sns.scatterplot(data=data)
plt.xticks(rotation=90)
plt.show()
plt.figure(figsize=(30,24))
sns.lineplot(data=data)
plt.xticks(rotation=90)
plt.show()

# %%
# top trending searches yearly
df = Trending_topics.top_charts(2023, hl='en-US', 
                tz=300, geo='GLOBAL') 
df=df.head(10) 
print(df)
# Out:
#                     title   exploreQuery
# 0  War in Israel and Gaza    Israel Gaza
# 1       Titanic submarine
# 2       Turkey earthquake
# 3        Hurricane Hilary
# 4        Hurricane Idalia
# 5           Hurricane Lee
# 6          Maine shooting
# 7      Nashville shooting
# 8           Chandrayaan-3  Chandrayaan 3
# 9            War in Sudan          Sudan

# %%
#keyword suggestions
kw_sug=input()
keywords = Trending_topics.suggestions( 
keyword=kw_sug) 
df = pd.DataFrame(keywords) 
# df=df.drop(columns= 'mid') 
print(df)
# Out:
#  Trump
#              mid         title                       type
# 0       /m/07gql       Trumpet                Instruments
# 1  /g/11c0xr0k6k     Trumpeter                      Topic
# 2      /m/01hp0l      Trumpton  British television series
# 3      /m/0cqt90  Donald Trump        45th U.S. President
# 4       /m/0m2w3        Myopia                    Disease
